# %% [markdown]
# # Plot astro images correctly using matplotlib

# %%
import sys
sys.path.append("..")
import numpy as np
import matplotlib.pyplot as plt
from astropy.wcs import WCS
import plotting

def generate_gaussian_xy(shape, x_c, y_c, sigma_a, sigma_b, theta_math, amplitude=100):
    """
    Generates a 2D Gaussian array with data[x, y] indexing.
    
    theta_math: Angle in radians from pixel +x (Right) toward pixel +y (Up).
    sigma_a: Major axis standard deviation.
    sigma_b: Minor axis standard deviation.
    """
    if sigma_b > sigma_a:
        raise ValueError("sigma_a must be the major axis (>= sigma_b)")
        
    # In data[x, y] convention, first axis must be X
    x, y = np.indices(shape)
    
    cos_t = np.cos(theta_math)
    sin_t = np.sin(theta_math)
    
    # Rotation transformation
    x_rot = (x - x_c) * cos_t + (y - y_c) * sin_t
    y_rot = -(x - x_c) * sin_t + (y - y_c) * cos_t
    
    g = amplitude * np.exp(-( (x_rot**2 / (2 * sigma_a**2)) + (y_rot**2 / (2 * sigma_b**2)) ))
    return g

def calculate_theta_math(data):
    """
    Recovers the pixel-space angle theta_math from data[x, y].
    Returns angle in radians in range [-pi/2, pi/2].
    """
    x_grid, y_grid = np.indices(data.shape)
    
    m00 = np.sum(data)
    if m00 <= 0: return np.nan
    
    # Centroids
    x_c = np.sum(x_grid * data) / m00
    y_c = np.sum(y_grid * data) / m00
    
    # Second-order central moments
    mu20 = np.sum((x_grid - x_c)**2 * data) / m00
    mu02 = np.sum((y_grid - y_c)**2 * data) / m00
    mu11 = np.sum((x_grid - x_c) * (y_grid - y_c) * data) / m00
    
    # Principal axis angle
    return 0.5 * np.arctan2(2 * mu11, mu20 - mu02)

def calculate_pa_from_wcs(data, wcs, beam=True):
    """
    Converts pixel theta_math to Astronomical Position Angle (PA).
    
    Assumptions:
    1. data is indexed as [x, y].
    2. PA is 0 at North, 90 at East.
    3. theta_math is from pixel +x axis toward pixel +y axis.
    if beam, returned angle satisfies -90 < pa <= 90
    otherwise 0 <= pa < 180
    """
    theta_math = calculate_theta_math(data)
    if np.isnan(theta_math):
        return np.nan

    # Get the transformation matrix
    m = wcs.pixel_scale_matrix
    
    # The direction of Celestial North (+Dec) in your pixel grid.
    # In the [x, y] convention, the second column of the matrix (m[0,1], m[1,1])
    # tells us how the pixel x and y components contribute to Declination.
    # We want the angle of the vector that points towards increasing Dec.
    north_pixel_angle = np.arctan2(m[1, 1], m[0, 1])
    
    # Parity: determinant is negative for East-Left (Standard FITS/CASA).
    # parity = -1
    det = np.linalg.det(m)
    parity = np.sign(det)
    
    # THE FIX: 
    # To get the sign you expect (North=0, moving toward West is negative):
    # We take (north_pixel_angle - theta_math).
    # Then multiply by parity to ensure Eastward movement is a positive increase.
    pa_rad = (north_pixel_angle - theta_math) * parity
    
    # Normalize to [0, 180) for elliptical symmetry
    pa_deg = np.degrees(pa_rad)
    pa_deg = ((pa_deg + 90) % 180) - 90 if beam else pa_deg % 180
    return pa_deg
    
def create_demo_wcs(shape):
    """Creates a standard East-Left, North-Up WCS."""
    w = WCS(naxis=2)
    w.wcs.crpix = [shape[0] / 2, shape[1] / 2]
    w.wcs.crval = [180.0, 0.0]
    w.wcs.ctype = ["RA---TAN", "DEC--TAN"]
    
    scale = 1.0 / 3600.0 # 1 arcsec/pixel
    w.wcs.cdelt = [-scale, scale] # East is -x, North is +y
    w.wcs.pc = [[1, 0], [0, 1]]
    return w

# --- DEMO EXECUTION ---

# 1. Setup
shape = (200, 200) # (width, height)
wcs = create_demo_wcs(shape)
plots = []

for target_theta_math in range(0, 360, 30):
    # 2. Define Target (e.g., North-East)
    # North is +y (90 deg), East is -x (180 deg).
    # North-East is halfway between them = 135 degrees.
    target_theta_math_rad = np.radians(target_theta_math)
    data = generate_gaussian_xy(shape, 100, 100, 20, 8, target_theta_math_rad)

    # 3. Analyze
    pa = calculate_pa_from_wcs(data, wcs, False)
    recovered_theta = np.degrees(calculate_theta_math(data))

    print(f"Input theta_math:     {target_theta_math:.2f}°")
    print(f"Recovered theta_math: {recovered_theta:.2f}°")
    print(f"Calculated Sky PA:    {pa:.2f} (Should be {target_theta_math - 90})")
    print()

    # 4. Plotting
    fig, ax = plotting.generate_astro_plot(data, wcs)
    # Draw Arrow showing the major axis in pixel space
    x0, y0 = 100, 100
    length = 40 
    ax.arrow(
        x0, y0, length*np.cos(np.radians(recovered_theta)), 
        length*np.sin(np.radians(recovered_theta)), 
        color='cyan', width=1, head_width=5, label='Major Axis'
    )
     
    ax.coords[0].set_axislabel('l')
    ax.coords[1].set_axislabel('m')
    ax.set_title(f"Sky PA: {pa:.2f}° | Pixel Theta: {recovered_theta:.2f}°")
    ax.legend()
    plots.append(fig)
    
plt.show()

# %%
from matplotlib.path import Path

def add_triangle(ary, corners_xy, value=1.0):
     """
     corners_xy: [(x0,y0), (x1,y1), (x2,y2)] in pixel indices
     """
     shape = ary.shape
     nx = shape[0]
     ny = shape[1]

     # Build pixel grid in (x,y) indexing
     x, y = np.meshgrid(np.arange(nx), np.arange(ny), indexing="ij")
     pts = np.column_stack([x.ravel(), y.ravel()])

     # Solid triangle mask
     tri = Path(corners_xy)
     mask = tri.contains_points(pts).reshape(nx, ny)

     # Write into a copy (2D DataArray)
     out = ary.copy()
     out[mask] = value
     return out

# %%
import sys
sys.path.append("..")

import numpy as np
import xarray as xr
import plotting
from wcs_reproject import build_wcs_from_xradio
from xradio.image import make_empty_sky_image

# Build a synthetic XRADIO image, then construct WCS as in the demo notebook.
phase_center = [0.0, 0.0]  # [ra, dec] in radians
image_size = [256, 256]
cell_arcsec = 2.0
cell = np.deg2rad(cell_arcsec / 3600.0)
cell_size = [cell, cell]
frequency_coords = np.array([1.4e9])
pol_coords = ["I"]
time_coords = np.array([59000.0])

xds = make_empty_sky_image(
    phase_center=phase_center,
    image_size=image_size,
    cell_size=cell_size,
    frequency_coords=frequency_coords,
    pol_coords=pol_coords,
    time_coords=time_coords,
    direction_reference="fk5",
    projection="SIN",
    spectral_reference="lsrk",
    do_sky_coords=True,
)

dims = ("time", "frequency", "polarization", "l", "m")
coords = {d: xds.coords[d] for d in dims}
sky_shape = tuple(len(coords[d]) for d in dims)
sky_data = np.zeros(sky_shape, dtype=np.float32)

# Add a simple off-center source so the plot has visible structure.
"""
sky_data = generate_gaussian_xy(
    shape=image_size, x_c=100, y_c=200, sigma_a=20, sigma_b=10,
    theta_math=np.radians(30), amplitude=100
)
"""
plane = sky_data[0, 0, 0]
corners_xy = [[40, 50], [150, 100], [170, 120]]
plane = add_triangle(plane, corners_xy, value=1.0)
sky_data[0, 0, 0] = plane
sky = xr.DataArray(sky_data, dims=dims, coords=coords)
sky.attrs["units"] = "Jy/pixel"
xds["SKY"] = sky


wcs_build_result = build_wcs_from_xradio(xds, dim_a="l", dim_b="m")
wcs = wcs_build_result.wcs

plane = xds["SKY"].isel(time=0, frequency=0, polarization=0).values
fig, ax = plotting.generate_astro_plot(plane, wcs)
ax.coords[0].set_axislabel("right ascension")
ax.coords[1].set_axislabel("declination")
ax.set_title("Synthetic XRADIO image plotted with build_wcs_from_xradio WCS")

# %%
from wcs_reproject import reproject_to_frame

# Reproject FK5 source to Galactic frame on a newly centered Galactic grid.
galactic = reproject_to_frame(
    xds,
    "galactic",
    keep_grid=False,
    method="bilinear",
    include_original_world_coords=True,
)
galactic

# %%
wcs_build_result = build_wcs_from_xradio(galactic, dim_a="l", dim_b="m")
wcs = wcs_build_result.wcs
print(wcs)

plane = galactic["SKY"].isel(time=0, frequency=0, polarization=0).values
fig, ax = plotting.generate_astro_plot(plane, wcs)
ax.coords[0].set_axislabel("galactic longitude")
ax.coords[1].set_axislabel("galacctic latitude")
ax.set_title("Galactic coords")

# %%
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord
from wcs_reproject import build_wcs_from_xradio

# Correct comparison: source-corner FK5 -> astropy Galactic -> target pixel -> sample target Galactic maps.
if "corners_xy" in globals():
    src_corners = [tuple(map(float, c)) for c in corners_xy]
else:
    n_l = int(xds.sizes["l"])
    n_m = int(xds.sizes["m"])
    src_corners = [(0.0, 0.0), (0.0, n_m - 1), (n_l - 1, 0.0), (n_l - 1, n_m - 1)]

tgt_wcs = build_wcs_from_xradio(galactic, dim_a="l", dim_b="m").wcs

ra_map = xds["right_ascension"].values
dec_map = xds["declination"].values
glon_map = galactic["galactic_longitude"].values
glat_map = galactic["galactic_latitude"].values

def bilinear_sample(arr, x, y):
    """Sample arr[x,y] at float pixel coordinates."""
    n_x, n_y = arr.shape
    x = float(np.clip(x, 0.0, n_x - 1.0))
    y = float(np.clip(y, 0.0, n_y - 1.0))
    x0 = int(np.floor(x)); x1 = min(x0 + 1, n_x - 1)
    y0 = int(np.floor(y)); y1 = min(y0 + 1, n_y - 1)
    dx = x - x0
    dy = y - y0
    v00 = arr[x0, y0]
    v10 = arr[x1, y0]
    v01 = arr[x0, y1]
    v11 = arr[x1, y1]
    return (
        (1 - dx) * (1 - dy) * v00
        + dx * (1 - dy) * v10
        + (1 - dx) * dy * v01
        + dx * dy * v11
    )

print("src_px(l,m) | tgt_px(l,m) | glon_ast_deg glat_ast_deg | glon_img_deg glat_img_deg | dlon_arcsec dlat_arcsec")

for l_src, m_src in src_corners:
    # Source corner FK5 world coordinates (sampled from source world maps).
    ra_rad = bilinear_sample(ra_map, l_src, m_src)
    dec_rad = bilinear_sample(dec_map, l_src, m_src)
    g = SkyCoord(ra=ra_rad * u.rad, dec=dec_rad * u.rad, frame="fk5", equinox="J2000").galactic
    glon_ast = float(g.l.to_value(u.rad))
    glat_ast = float(g.b.to_value(u.rad))

    # Map astropy Galactic world coord to target pixel coordinates.
    l_tgt, m_tgt = tgt_wcs.wcs_world2pix(np.degrees(glon_ast), np.degrees(glat_ast), 0)
    glon_img = bilinear_sample(glon_map, l_tgt, m_tgt)
    glat_img = bilinear_sample(glat_map, l_tgt, m_tgt)
    dlon = np.arctan2(np.sin(glon_img - glon_ast), np.cos(glon_img - glon_ast))
    dlat = glat_img - glat_ast

    print(
        f"({l_src:7.2f},{m_src:7.2f}) | ({l_tgt:8.3f},{m_tgt:8.3f}) | "
        f"{np.degrees(glon_ast):11.6f} {np.degrees(glat_ast):11.6f} | "
        f"{np.degrees(glon_img):11.6f} {np.degrees(glat_img):11.6f} | "
        f"{np.degrees(dlon) * 3600.0:10.3f} {np.degrees(dlat) * 3600.0:10.3f}"
    )

# %%
import sys
sys.path.append("..")

import numpy as np
import xarray as xr
import plotting
from wcs_reproject import build_wcs_from_xradio
from xradio.image import make_empty_sky_image

# Build a synthetic XRADIO image, then construct WCS as in the demo notebook.
phase_center = [0.0, 0.0]  # [ra, dec] in radians
image_size = [256, 256]
cell_arcsec = 2.0
cell = np.deg2rad(cell_arcsec / 3600.0)
cell_size = [cell, cell]
frequency_coords = np.array([1.4e9])
pol_coords = ["I"]
time_coords = np.array([59000.0])

xds = make_empty_sky_image(
    phase_center=phase_center,
    image_size=image_size,
    cell_size=cell_size,
    frequency_coords=frequency_coords,
    pol_coords=pol_coords,
    time_coords=time_coords,
    direction_reference="fk5",
    projection="SIN",
    spectral_reference="lsrk",
    do_sky_coords=True,
)

dims = ("time", "frequency", "polarization", "l", "m")
coords = {d: xds.coords[d] for d in dims}
sky_shape = tuple(len(coords[d]) for d in dims)
sky_data = np.zeros(sky_shape, dtype=np.float32)

# Add a simple off-center source so the plot has visible structure.

plane = sky_data[0, 0, 0]
corners_xy = [[40, 50], [150, 100], [170, 120]]
for c in corners_xy:
    plane[tuple(c)] = 1
sky_data[0, 0, 0] = plane
sky = xr.DataArray(sky_data, dims=dims, coords=coords)
sky.attrs["units"] = "Jy/pixel"
xds["SKY"] = sky


wcs_build_result = build_wcs_from_xradio(xds, dim_a="l", dim_b="m")
wcs = wcs_build_result.wcs

plane = xds["SKY"].isel(time=0, frequency=0, polarization=0).values
fig, ax = plotting.generate_astro_plot(plane, wcs)
ax.coords[0].set_axislabel("right ascension")
ax.coords[1].set_axislabel("declination")
ax.set_title("Synthetic XRADIO image plotted with build_wcs_from_xradio WCS")

# %%
from wcs_reproject import reproject_to_frame

# Reproject FK5 source to Galactic frame on a newly centered Galactic grid.
galactic = reproject_to_frame(
    xds,
    "galactic",
    keep_grid=False,
    method="bilinear",
    include_original_world_coords=True,
)
galactic

# %%
wcs_build_result = build_wcs_from_xradio(galactic, dim_a="l", dim_b="m")
wcs = wcs_build_result.wcs
print(wcs)

plane = galactic["SKY"].isel(time=0, frequency=0, polarization=0).values
fig, ax = plotting.generate_astro_plot(plane, wcs)
ax.coords[0].set_axislabel("galactic longitude")
ax.coords[1].set_axislabel("galacctic latitude")
ax.set_title("Galactic coords")

# %%
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord
from wcs_reproject import build_wcs_from_xradio, reproject_to_frame

# Ensure target reprojection exists even when this cell is run directly.
if "galactic" not in globals():
    galactic = reproject_to_frame(
        xds,
        "galactic",
        keep_grid=False,
        method="bilinear",
        include_original_world_coords=True,
    )

# Correct comparison: source-corner FK5 -> astropy Galactic -> target pixel -> sample target Galactic maps.
if "corners_xy" in globals():
    src_corners = [tuple(map(float, c)) for c in corners_xy]
else:
    n_l = int(xds.sizes["l"])
    n_m = int(xds.sizes["m"])
    src_corners = [(0.0, 0.0), (0.0, n_m - 1), (n_l - 1, 0.0), (n_l - 1, n_m - 1)]

tgt_wcs = build_wcs_from_xradio(galactic, dim_a="l", dim_b="m").wcs
tgt_wcs

# %%
ra_map = xds["right_ascension"]
dec_map = xds["declination"]
glon_map = galactic["galactic_longitude"]
glat_map = galactic["galactic_latitude"]

gal_pix_nonzero = list(map(tuple, np.argwhere(galactic["SKY"][0, 0, 0].values > 0)))

print("non zero pixel coords and values in galactic image")
values = []
for p in gal_pix_nonzero: 
    v = galactic["SKY"][(0, 0, 0) + p].item()
    values.append(v)
    print(int(p[0]), int(p[1]), v)

# I know the results of the above loop here
g1 = slice(0, 3)
g2 = slice(4, 9)
g3 = slice(9, len(values))
out_corners = []
for i, g in enumerate([g1, g2, g3]):
    max_loc = gal_pix_nonzero[g][np.argmax(values[g])]
    out_corners.append(max_loc)
    print(
        f"group {i} sum {np.sum(values[g])} "
        f"max at {int(max_loc[0])}, {int(max_loc[1])}"
    )
print("out_corners", out_corners)




print("src_px(l,m) | tgt_px(l,m) | glon_ast_deg glat_ast_deg | glon_img_deg glat_img_deg | dlon_arcsec dlat_arcsec")

count = 0
for l_src, m_src in src_corners:
    l = int(l_src)
    m = int(m_src)
    # Source corner FK5 world coordinates (sampled from source world maps).
    ra_inp_rad = ra_map.isel(l=l, m=m).item()
    dec_inp_rad = dec_map.isel(l=l, m=m).item()
    
    g_astropy = SkyCoord(ra=ra_inp_rad * u.rad, dec=dec_inp_rad * u.rad, frame="fk5", equinox="J2000").galactic
    # print("g_astropy", g_astropy)
    glon_astropy = float(g_astropy.l.to_value(u.rad))
    glat_astropy = float(g_astropy.b.to_value(u.rad))
    l_tgt = out_corners[count][0]
    m_tgt = out_corners[count][1]
    glon_reproject = galactic["galactic_longitude"].isel(l=l_tgt, m=m_tgt).item()
    glat_reproject = galactic["galactic_latitude"].isel(l=l_tgt, m=m_tgt).item()

    print(f"astropy   {glon_astropy:13.10f}, {glat_astropy:13.10f}")
    print(f"reproject {glon_reproject:13.10f}, {glat_reproject:13.10f}")
    print(
        f"astropy - reproject {3600*np.degrees(glon_astropy - glon_reproject)*np.cos(glat_astropy)}, "
        + f"{3600*np.degrees(glat_astropy - glat_reproject)}"
    )
          
    print()

    """
    # Map astropy Galactic world coord to target pixel coordinates.
    l_tgt, m_tgt = tgt_wcs.wcs_world2pix(np.degrees(glon_ast), np.degrees(glat_ast), 0)
    l_tgt = int(l_tgt)
    m_tgt = int(m_tgt)
    glon_img = glon_map.isel(l=l_tgt, m=m_tgt).item()
    glat_img = glat_map.isel(l=l_tgt, m=m_tgt).item()
    #dlon = np.arctan2(np.sin(glon_img - glon_ast), np.cos(glon_img - glon_ast))
   # dlat = glat_img - glat_ast

    print(
        f"({l_src:7.2f},{m_src:7.2f}) | ({l_tgt:8.3f},{m_tgt:8.3f}) | "
        f"{np.degrees(glon_ast):11.6f} {np.degrees(glat_ast):11.6f} | "
        f"{np.degrees(glon_img):11.6f} {np.degrees(glat_img):11.6f} | "
        #f"{np.degrees(dlon) * 3600.0:10.3f} {np.degrees(dlat) * 3600.0:10.3f}"
    )
    """
    count += 1
